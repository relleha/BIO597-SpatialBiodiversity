# %% [markdown]
# # Assignment 01: More Practice With GeoPandas
#
# ## BIO597 Spatial Analysis of Biodiversity
#
# This assignment gives you more practice with the workflow from Lab 01:
#
# * load a CSV file of species occurrence records
# * turn longitude and latitude columns into point geometry
# * plot occurrence records on an interactive map
# * combine multiple species into one `GeoDataFrame`
# * run a few simple spatial summaries
#
# You should expect to write some code in this notebook. Some cells are partly filled in, but you will need to complete the missing pieces.
#
# Remember, learning to code is often times about learning how to strategically copy/paste/modify. At first everything will seem arbitrary, but with repetition it will become common-place and will begin to make sense.
#
# **Assignment 01 is due by next Thursday Sept 10th at 5pm**

# %% [markdown]
# ## Data
#
# Use the coordinate files in `../labs/EasternSnakes`. Each CSV file has the same basic structure:
#
# * `ID`: occurrence record identifier
# * `Longitude`: east-west coordinate
# * `Latitude`: north-south coordinate
#
# Because this assignment notebook is in the `assignments` folder, the file paths below start with `../labs/EasternSnakes/`.

# %% [markdown]
# ## 1. Import the packages
#
# We need `geopandas` for geospatial data and `pandas` for combining tables. Run this cell before running the rest of the notebook.

# %%
import geopandas as gpd
import pandas as pd

# Is there visual confirmation that a code cell has run correctly if there is nothing called for visualization? Or just lack of error code?

# Is there a way to reference cells or lines of code within cells by number?

# %% [markdown]
# ## 2. Load the first species table
#
# Start with corn snake, *Pantherophis guttatus*. The first goal is only to read the CSV file and inspect the first few rows.
#
# Complete the filename in the first line, then run the cell.

# %%
pguttatus_csv = "../labs/EasternSnakes/Pguttatus_coords.csv"

pguttatus_df = gpd.read_file(pguttatus_csv)
pguttatus_df.head()
# Out:
#             ID    Longitude    Latitude
# 0     LSU99213  -93.2097528  30.6562667
# 1     OMNH9224    -99.84569     35.0155
# 2     OMNH8361    -93.82875     34.4087
# 3  FLMNH153506    -90.89277   31.886388
# 4  FLMNH151609  -104.399627   33.392876

# %% [markdown]
# ## 3. Convert the first species to a GeoDataFrame
#
# The table has longitude and latitude columns, but those columns are not yet geometry. Use `gpd.points_from_xy()` to make point geometry.
#
# Fill in the longitude and latitude column names. Look back at the output from the previous cell if you need a reminder.

# %%
pguttatus_gdf = gpd.GeoDataFrame(
    pguttatus_df,
    geometry=gpd.points_from_xy(pguttatus_df["Longitude"], pguttatus_df["Latitude"]),
    crs="EPSG:4326",
)

pguttatus_gdf["Species"] = "Pantherophis guttatus"
pguttatus_gdf.head()
# Out:
#             ID    Longitude    Latitude                     geometry  \
# 0     LSU99213  -93.2097528  30.6562667   POINT (-93.20975 30.65627)
# 1     OMNH9224    -99.84569     35.0155    POINT (-99.84569 35.0155)
# 2     OMNH8361    -93.82875     34.4087    POINT (-93.82875 34.4087)
# 3  FLMNH153506    -90.89277   31.886388   POINT (-90.89277 31.88639)
# 4  FLMNH151609  -104.399627   33.392876  POINT (-104.39963 33.39288)
#
#                  Species
# 0  Pantherophis guttatus
# 1  Pantherophis guttatus
# 2  Pantherophis guttatus
# 3  Pantherophis guttatus
# 4  Pantherophis guttatus

# %% [markdown]
# ## 4. Map the first species
#
# Use `.explore()` to make a quick interactive map. This is a visual check that the coordinates are being interpreted correctly.

# %%
pguttatus_gdf.explore() 
# Why does gpd not need to be explicitly called here, but is called in other functions?
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea42aa2f9c48239c82a3454f8f513c5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea42aa2f9c48239c82a3454f8f513c5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea42aa2f9c48239c82a3454f8f513c5b = L.map(
#                 &quot;map_ea42aa2f9c48239c82a3454f8f513c5b&quot;,
#                 {
#                     center: [33.039306665, -92.193495],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ea42aa2f9c48239c82a3454f8f513c5b);
#
#
#
#
#
#             var tile_layer_4ab902f70d728c9386393399fd0c5360 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ab902f70d728c9386393399fd0c5360.addTo(map_ea42aa2f9c48239c82a3454f8f513c5b);
#
#
#             map_ea42aa2f9c48239c82a3454f8f513c5b.fitBounds(
#                 [[26.46783333, -108.2453], [39.61078, -76.14169]],
#                 {}
#             );
#
#
#         function geo_json_801875657ef87cdc37d5001f953d85a8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_801875657ef87cdc37d5001f953d85a8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_801875657ef87cdc37d5001f953d85a8_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_801875657ef87cdc37d5001f953d85a8_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_801875657ef87cdc37d5001f953d85a8_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_801875657ef87cdc37d5001f953d85a8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_801875657ef87cdc37d5001f953d85a8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_801875657ef87cdc37d5001f953d85a8 = L.geoJson(null, {
#                 onEachFeature: geo_json_801875657ef87cdc37d5001f953d85a8_onEachFeature,
#
#                 style: geo_json_801875657ef87cdc37d5001f953d85a8_styler,
#                 pointToLayer: geo_json_801875657ef87cdc37d5001f953d85a8_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_801875657ef87cdc37d5001f953d85a8_add (data) {
#             geo_json_801875657ef87cdc37d5001f953d85a8
#                 .addData(data);
#         }
#             geo_json_801875657ef87cdc37d5001f953d85a8_add({&quot;bbox&quot;: [-108.2453, 26.46783333, -76.14169, 39.61078], &quot;features&quot;: [{&quot;bbox&quot;: [-93.2097528, 30.6562667, -93.2097528, 30.6562667], &quot;geometry&quot;: {&quot;coordinates&quot;: [-93.2097528, 30.6562667], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ID&quot;: &quot;LSU99213&quot;, &quot;Latitude&quot;: &quot;30.6562667&quot;, &quot;Longitude&quot;: &quot;-93.2097528&quot;, &quot;Species&quot;: &qu

# %% [markdown]
# ## 5. Repeat the workflow for a second species
#
# Now load common kingsnake, *Lampropeltis getula*. This cell should do two things: read the CSV and show the first few rows.
#
# Fill in the filename.

# %%
lgetula_csv = "../labs/EasternSnakes/Lgetula_coords.csv"

lgetula_df = gpd.read_file(lgetula_csv)
lgetula_df.head()

# Is there an equivalent to rstudio's environment, where all working objects can be viewed in a list?
# Out:
#           ID   Longitude   Latitude
# 0   KU289566   -92.02992   32.55354
# 1  MVZ175927   -78.76421   35.72642
# 2  MVZ137799    -82.2377    32.7824
# 3  OMNH12624  -97.218056  35.220833
# 4   OMNH5006   -95.98857   34.46144

# %% [markdown]
# ## 6. Convert the second species to a GeoDataFrame
#
# Use the same pattern from the first species. Make sure the `Species` column contains the correct scientific name.

# %%
lgetula_gdf = gpd.GeoDataFrame(
    lgetula_df,
    geometry=gpd.points_from_xy(lgetula_df["Longitude"], lgetula_df["Latitude"]),
    crs="EPSG:4326",
)

lgetula_gdf["Species"] = "Lampropeltis getula"
lgetula_gdf.head()
# Out:
#           ID   Longitude   Latitude                    geometry  \
# 0   KU289566   -92.02992   32.55354  POINT (-92.02992 32.55354)
# 1  MVZ175927   -78.76421   35.72642  POINT (-78.76421 35.72642)
# 2  MVZ137799    -82.2377    32.7824    POINT (-82.2377 32.7824)
# 3  OMNH12624  -97.218056  35.220833  POINT (-97.21806 35.22083)
# 4   OMNH5006   -95.98857   34.46144  POINT (-95.98857 34.46144)
#
#                Species
# 0  Lampropeltis getula
# 1  Lampropeltis getula
# 2  Lampropeltis getula
# 3  Lampropeltis getula
# 4  Lampropeltis getula

# %% [markdown]
# ## 7. Map the second species
#
# Create an interactive map for *Lampropeltis getula*.

# %%
# Replace the blank with the GeoDataFrame you created above.
lgetula_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82e1c116108abdfa0c65f73189eba389 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82e1c116108abdfa0c65f73189eba389&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82e1c116108abdfa0c65f73189eba389 = L.map(
#                 &quot;map_82e1c116108abdfa0c65f73189eba389&quot;,
#                 {
#                     center: [34.3870645, -89.95456335],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_82e1c116108abdfa0c65f73189eba389);
#
#
#
#
#
#             var tile_layer_dbb0a045d82c8ef2898ab5591089dbf0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbb0a045d82c8ef2898ab5591089dbf0.addTo(map_82e1c116108abdfa0c65f73189eba389);
#
#
#             map_82e1c116108abdfa0c65f73189eba389.fitBounds(
#                 [[29.524469, -101.1449167], [39.24966, -78.76421]],
#                 {}
#             );
#
#
#         function geo_json_4a06b4f8a90a228c72cff1b03099011f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4a06b4f8a90a228c72cff1b03099011f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4a06b4f8a90a228c72cff1b03099011f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_4a06b4f8a90a228c72cff1b03099011f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4a06b4f8a90a228c72cff1b03099011f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4a06b4f8a90a228c72cff1b03099011f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4a06b4f8a90a228c72cff1b03099011f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4a06b4f8a90a228c72cff1b03099011f = L.geoJson(null, {
#                 onEachFeature: geo_json_4a06b4f8a90a228c72cff1b03099011f_onEachFeature,
#
#                 style: geo_json_4a06b4f8a90a228c72cff1b03099011f_styler,
#                 pointToLayer: geo_json_4a06b4f8a90a228c72cff1b03099011f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_4a06b4f8a90a228c72cff1b03099011f_add (data) {
#             geo_json_4a06b4f8a90a228c72cff1b03099011f
#                 .addData(data);
#         }
#             geo_json_4a06b4f8a90a228c72cff1b03099011f_add({&quot;bbox&quot;: [-101.1449167, 29.524469, -78.76421, 39.24966], &quot;features&quot;: [{&quot;bbox&quot;: [-92.02992, 32.55354, -92.02992, 32.55354], &quot;geometry&quot;: {&quot;coordinates&quot;: [-92.02992, 32.55354], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ID&quot;: &quot;KU289566&quot;, &quot;Latitude&quot;: &quot;32.55354&quot;, &quot;Longitude&quot;: &quot;-92.02992&quot;, &quot;Species&quot;: &quot;Lampropelti

# %% [markdown]
# ## 8. Add a third species
#
# Choose coachwhip, *Masticophis flagellum*. This time, write most of the code yourself.
#
# Your cell should:
#
# * load `Mflagellum_coords.csv`
# * convert it to a `GeoDataFrame`
# * add a `Species` column
# * show the first few rows

# %%
# Write your code here.
# Use the same pattern from the first two species.

mflagellum_csv = "../labs/EasternSnakes/Mflagellum_coords.csv"

mflagellum_df = gpd.read_file(mflagellum_csv)
mflagellum_df.head()

mflagellum_gdf = gpd.GeoDataFrame(
    mflagellum_df,
    geometry=gpd.points_from_xy(mflagellum_df["Longitude"], mflagellum_df["Latitude"]),
    crs="EPSG:4326",
)

mflagellum_gdf["Species"] = "Masticophis flagellum"
mflagellum_gdf.head()
# Out:
#            ID  Longitude  Latitude                    geometry  \
# 0  AMCC266297  -84.36819  31.32126  POINT (-84.36819 31.32126)
# 1  AMCC266279  -85.02119  31.67147  POINT (-85.02119 31.67147)
# 2  AMCC266288  -81.44868  27.85655  POINT (-81.44868 27.85655)
# 3  AMCC266300  -83.51659  32.66002  POINT (-83.51659 32.66002)
# 4  AMCC266302  -82.50691  32.03915  POINT (-82.50691 32.03915)
#
#                  Species
# 0  Masticophis flagellum
# 1  Masticophis flagellum
# 2  Masticophis flagellum
# 3  Masticophis flagellum
# 4  Masticophis flagellum

# %% [markdown]
# ## 9. Map the third species
#
# Make an interactive map for the third species.

# %%
# Write one line of code using .explore().
mflagellum_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27c42b5942319287e94f4e8a2f0d145f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27c42b5942319287e94f4e8a2f0d145f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27c42b5942319287e94f4e8a2f0d145f = L.map(
#                 &quot;map_27c42b5942319287e94f4e8a2f0d145f&quot;,
#                 {
#                     center: [30.258285, -83.85567499999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_27c42b5942319287e94f4e8a2f0d145f);
#
#
#
#
#
#             var tile_layer_b43de55142b59df9deb6816ab1f54021 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b43de55142b59df9deb6816ab1f54021.addTo(map_27c42b5942319287e94f4e8a2f0d145f);
#
#
#             map_27c42b5942319287e94f4e8a2f0d145f.fitBounds(
#                 [[27.85655, -86.26267], [32.66002, -81.44868]],
#                 {}
#             );
#
#
#         function geo_json_72978b3212b930f6112260fa8552adb5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_72978b3212b930f6112260fa8552adb5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_72978b3212b930f6112260fa8552adb5_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_72978b3212b930f6112260fa8552adb5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_72978b3212b930f6112260fa8552adb5_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_72978b3212b930f6112260fa8552adb5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_72978b3212b930f6112260fa8552adb5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_72978b3212b930f6112260fa8552adb5 = L.geoJson(null, {
#                 onEachFeature: geo_json_72978b3212b930f6112260fa8552adb5_onEachFeature,
#
#                 style: geo_json_72978b3212b930f6112260fa8552adb5_styler,
#                 pointToLayer: geo_json_72978b3212b930f6112260fa8552adb5_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_72978b3212b930f6112260fa8552adb5_add (data) {
#             geo_json_72978b3212b930f6112260fa8552adb5
#                 .addData(data);
#         }
#             geo_json_72978b3212b930f6112260fa8552adb5_add({&quot;bbox&quot;: [-86.26267, 27.85655, -81.44868, 32.66002], &quot;features&quot;: [{&quot;bbox&quot;: [-84.36819, 31.32126, -84.36819, 31.32126], &quot;geometry&quot;: {&quot;coordinates&quot;: [-84.36819, 31.32126], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ID&quot;: &quot;AMCC266297&quot;, &quot;Latitude&quot;: &quot;31.32126&quot;, &quot;Longitude&quot;: &quot;-84.36819&quot;, &quot;Species&quot;: &quot;Masticophis

# %% [markdown]
# ## 10. Combine the three species
#
# Use `pd.concat()` to combine the three GeoDataFrames into one object. Keep this cell focused on combining the data and checking the result.

# %%
combined_snakes = pd.concat([pguttatus_gdf, lgetula_gdf, mflagellum_gdf])

combined_snakes.head() 
# Is there a way to see more than the first five records, e.g., to check that all species were concatenated?
# Out:
#             ID    Longitude    Latitude                     geometry  \
# 0     LSU99213  -93.2097528  30.6562667   POINT (-93.20975 30.65627)
# 1     OMNH9224    -99.84569     35.0155    POINT (-99.84569 35.0155)
# 2     OMNH8361    -93.82875     34.4087    POINT (-93.82875 34.4087)
# 3  FLMNH153506    -90.89277   31.886388   POINT (-90.89277 31.88639)
# 4  FLMNH151609  -104.399627   33.392876  POINT (-104.39963 33.39288)
#
#                  Species
# 0  Pantherophis guttatus
# 1  Pantherophis guttatus
# 2  Pantherophis guttatus
# 3  Pantherophis guttatus
# 4  Pantherophis guttatus

# %% [markdown]
# ## 11. Map all three species together
#
# Map the combined data. Color the points by the `Species` column so the species are easier to compare. Choose a different colormap to color these points from the [python colormap reference](https://matplotlib.org/stable/gallery/color/colormap_reference.html).

# %%
combined_snakes.explore(column="Species", cmap="gist_rainbow")
# I am not really liking any of the palettes I'm trying, which are selecting at least two similar colors even when the palette has diverging colors 
# (and doesn't seem to be choosing colors as ordered in sequence by display)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2a1391bf9a3214766dd5c399c5894d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Species&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Species&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0029&#x27;&gt;&lt;/span&gt;Lampropeltis getula&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#00ff89&#x27;&gt;&lt;/span&gt;Masticophis flagellum&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff00bf&#x27;&gt;&lt;/span&gt;Pantherophis guttatus&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2a1391bf9a3214766dd5c399c5894d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2a1391bf9a3214766dd5c399c5894d2 = L.map(
#                 &quot;map_b2a1391bf9a3214766dd5c399c5894d2&quot;,
#                 {
#                     center: [33.039306665, -92.193495],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b2a1391bf9a3214766dd5c399c5894d2);
#
#
#
#
#
#             var tile_layer_900ff4488e358d89a0e0c245699d149e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_900ff4488e358d89a0e0c245699d149e.addTo(map_b2a1391bf9a3214766dd5c399c5894d2);
#
#
#             map_b2a1391bf9a3214766dd5c399c5894d2.fitBounds(
#                 [[26.46783333, -108.2453], [39.61078, -76.14169]],
#                 {}
#             );
#
#
#         function geo_json_7797fc463a706901931b5baa795310b0_styler(feature) {
#             switch(feature.properties.ID) {
#                 case &quot;KU289566&quot;: case &quot;MVZ175927&quot;: case &quot;MVZ137799&quot;: case &quot;OMNH12624&quot;: case &quot;OMNH5006&quot;: case &quot;OMNH6115&quot;: case &quot;OMNH6645&quot;: case &quot;FLMNH173933&quot;: case &quot;FLMNH173210&quot;: case &quot;UTEP20919&quot;: case &quot;FHSM7738&quot;: case &quot;FHSM9864&quot;: case &quot;FHSM11300&quot;: case &quot;FHSM11506&quot;: case &quot;FHSM12472&quot;: case &quot;FHSM13092&quot;: case &quot;FHSM13917&quot;: case &quot;FHSM15266&quot;: case &quot;FHSM15645&quot;: case &quot;FHSM15709&quot;: case &quot;DBS2706&quot;: case &quot;DBS2766&qu

# %% [markdown]
# ## 12. Count the records for each species
#
# A very basic summary is the number of occurrence records per species. Use `groupby()` with the `Species` column.

# %%
record_counts = combined_snakes.groupby("Species").size()
record_counts
# Out:
# Species
# Lampropeltis getula      35
# Masticophis flagellum     9
# Pantherophis guttatus    36
# dtype: int64

# %% [markdown]
# ## 13. Find the overall coordinate bounds
#
# `total_bounds` gives the smallest rectangle that contains all the points. The output is four numbers: minimum longitude, minimum latitude, maximum longitude, and maximum latitude.
#
# Run the cell, then answer the question in the markdown cell below it.

# %%
combined_snakes.total_bounds
# Out:
# array([-108.2453    ,   26.46783333,  -76.14169   ,   39.61078   ])

# %% [markdown]
# **Question:** Based on `total_bounds`, what is the approximate western edge, eastern edge, southern edge, and northern edge of these combined records?
#
# **Your answer:** West-central CO, east VA, south Texas, north Kansas (I am not positive that this is the question being asked, but not sure how else to interpret)

# %% [markdown]
# ## 14. Project the data before measuring area
#
# Longitude and latitude are measured in degrees. Area measured in degrees is not easy to interpret, so project the data to `EPSG:5070` before calculating polygon areas.

# %%
combined_projected = combined_snakes.to_crs("EPSG:5070")
combined_projected.crs
# Out:
# <Projected CRS: EPSG:5070>
# Name: NAD83 / Conus Albers
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - CONUS onshore - Alabama; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming.
# - bounds: (-124.79, 24.41, -66.91, 49.38)
# Coordinate Operation:
# - name: Conus Albers
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ## 15. Make a convex hull for each species
#
# A convex hull is a simple polygon drawn around a set of points. It is not the true species range, but it is a useful first practice tool.
#
# This cell does three things: groups records by species, turns each group into a convex hull, and maps the hulls.

# %%
hulls_projected = combined_projected.dissolve(by="Species")
hulls_projected = hulls_projected.reset_index()
# What is the funciton of reset_index?

hulls_projected["geometry"] = hulls_projected.geometry.convex_hull

hulls = hulls_projected.to_crs(combined_snakes.crs)
hulls.explore(column="Species", cmap="rainbow")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73cde222539ee6c7d5374f61e9a1c14c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Species&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Species&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8000ff&#x27;&gt;&lt;/span&gt;Lampropeltis getula&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#80ffb4&#x27;&gt;&lt;/span&gt;Masticophis flagellum&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0000&#x27;&gt;&lt;/span&gt;Pantherophis guttatus&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73cde222539ee6c7d5374f61e9a1c14c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73cde222539ee6c7d5374f61e9a1c14c = L.map(
#                 &quot;map_73cde222539ee6c7d5374f61e9a1c14c&quot;,
#                 {
#                     center: [33.039306665, -92.193495],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_73cde222539ee6c7d5374f61e9a1c14c);
#
#
#
#
#
#             var tile_layer_679f967a4f7652c2adb0d987dd18bf45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_679f967a4f7652c2adb0d987dd18bf45.addTo(map_73cde222539ee6c7d5374f61e9a1c14c);
#
#
#             map_73cde222539ee6c7d5374f61e9a1c14c.fitBounds(
#                 [[26.46783333000001, -108.2453], [39.61077999999999, -76.14169]],
#                 {}
#             );
#
#
#         function geo_json_51d4d5a9c1e9b07de7f6a5772940c940_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#8000ff&quot;, &quot;fillColor&quot;: &quot;#8000ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#80ffb4&quot;, &quot;fillColor&quot;: &quot;#80ffb4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#ff0000&quot;, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }

# %% [markdown]
# ## 16. Calculate convex hull area
#
# `hulls_projected.area` gives area in square meters because `EPSG:5070` uses meters. Divide by 1,000,000 to convert square meters to square kilometers.
#
# Fill in the missing column name.

# %%
hulls["convex_hull_area_km2"] = hulls_projected.area / 1000000

hulls[["Species", "convex_hull_area_km2"]]
# Out:
#                  Species  convex_hull_area_km2
# 0    Lampropeltis getula          1.670557e+06
# 1  Masticophis flagellum          1.102008e+05
# 2  Pantherophis guttatus          3.122832e+06

# %% [markdown]
# **Question:** Which species has the largest convex hull area in your result? Give one biological or sampling reason why a species might have a larger hull area than another species.
#
# **Your answer:** Pantherophis guttatus. Perhaps this species has a broader niche than the other two sampled species.

# %% [markdown]
# ## 17. Choose one more species
#
# Choose one additional CSV file from `../labs/EasternSnakes` that you did not already use. Load it, convert it to a `GeoDataFrame`, add a `Species` column, and map it.
#
# This is meant to check that you can repeat the workflow without step-by-step scaffolding.

# %%
# Write your code here.
ferytrogramma_csv = "../labs/EasternSnakes/Ferytrogramma_coords.csv"

ferytrogramma_df = gpd.read_file(ferytrogramma_csv)
ferytrogramma_df.head()

ferytrogramma_gdf = gpd.GeoDataFrame(
    ferytrogramma_df,
    geometry=gpd.points_from_xy(ferytrogramma_df["Longitude"], ferytrogramma_df["Latitude"]),
    crs="EPSG:4326",
)

ferytrogramma_gdf["Species"] = "Farancia erytrogramma"
ferytrogramma_gdf.head()

ferytrogramma_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_679c4f162f97e8bb3a53f8dad2c357be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_679c4f162f97e8bb3a53f8dad2c357be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_679c4f162f97e8bb3a53f8dad2c357be = L.map(
#                 &quot;map_679c4f162f97e8bb3a53f8dad2c357be&quot;,
#                 {
#                     center: [33.40243, -82.9556855],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_679c4f162f97e8bb3a53f8dad2c357be);
#
#
#
#
#
#             var tile_layer_9149167104fb2dab3b6bae10081ad88c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9149167104fb2dab3b6bae10081ad88c.addTo(map_679c4f162f97e8bb3a53f8dad2c357be);
#
#
#             map_679c4f162f97e8bb3a53f8dad2c357be.fitBounds(
#                 [[30.26653, -90.109871], [36.53833, -75.8015]],
#                 {}
#             );
#
#
#         function geo_json_239e9baf6da80705466a5f627677b696_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_239e9baf6da80705466a5f627677b696_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_239e9baf6da80705466a5f627677b696_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_239e9baf6da80705466a5f627677b696_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_239e9baf6da80705466a5f627677b696_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_239e9baf6da80705466a5f627677b696.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_239e9baf6da80705466a5f627677b696_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_239e9baf6da80705466a5f627677b696 = L.geoJson(null, {
#                 onEachFeature: geo_json_239e9baf6da80705466a5f627677b696_onEachFeature,
#
#                 style: geo_json_239e9baf6da80705466a5f627677b696_styler,
#                 pointToLayer: geo_json_239e9baf6da80705466a5f627677b696_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_239e9baf6da80705466a5f627677b696_add (data) {
#             geo_json_239e9baf6da80705466a5f627677b696
#                 .addData(data);
#         }
#             geo_json_239e9baf6da80705466a5f627677b696_add({&quot;bbox&quot;: [-90.109871, 30.26653, -75.8015, 36.53833], &quot;features&quot;: [{&quot;bbox&quot;: [-81.965313, 32.80377, -81.965313, 32.80377], &quot;geometry&quot;: {&quot;coordinates&quot;: [-81.965313, 32.80377], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ID&quot;: &quot;F_erytrogramma_FE_1&quot;, &quot;Latitude&quot;: &quot;32.80377&quot;, &quot;Longitude&quot;: &quot;-81.965313&quot;, &quot;Species&quot;: &quot;Faranci

# %% [markdown]
# ## 18. What are one or two other interesting biological questions you could ask about this data?

# %% [markdown]
# # Write your questions here.
# What environmental characteristics are present where the species' convex hulls overlap? What environmental differences are detectable where convex hulls do not overlap?

# %% [markdown]
# ## 19. Submit your work
#
# Before submitting, make sure you have run the notebook from top to bottom and answered the written questions.
#
# Commit and push your completed notebook to your class GitHub repository.
